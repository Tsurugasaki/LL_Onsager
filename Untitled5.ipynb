# %% [markdown]
# # title
# details

# %%
import numpy as np                     # import and create an alias for numpy for numerical operations
import pandas as pd                    # "  pandas to handle spreadsheets

import matplotlib as mpl               # "  matplotlib, the fundamental plotting toolset
from matplotlib import pyplot as plt   # "  pyplot, a very commonly used subset of tools.
import seaborn as sns                  # "  seaborn to create high-level figures <-- the main tool today

# %% [markdown]
# ### import data from equation
#
# HEre I use ohoihglhlds

# %%
df_solutions_of_LH_0 = pd.read_csv('Ne_unstable_solutions_of_LHH=0_with_logs.csv')   # import a csv in a dataframe
df_solutions_of_LH_0
# Out:
#       LSiSi/LNaNa LSiSi/LHH  log_a  log_b
# 0               b         c   1.21   1.92
# 1               b         c   1.21   1.93
# 2               b         c   1.21   1.94
# 3               b         c   1.21   1.95
# 4               b         c   1.21   1.96
# ...           ...       ...    ...    ...
# 17258           b         c   3.00   1.96
# 17259           b         c   3.00   1.97
# 17260           b         c   3.00   1.98
# 17261           b         c   3.00   1.99
# 17262           b         c   3.00   2.00
#
# [17263 rows x 4 columns]

# %%
fig, ax = plt.subplots()     # create handles for the figure and axis object using the function `subplots` 

x = df_solutions_of_LH_0['log_a'].values   # extract x-coordinates from dataframe (right side of equation can also be directly written in the plot command) 
y = df_solutions_of_LH_0['log_b'].values   # extract y-coordinates from dataframe

ax.scatter(x,y)            # plot the coordinates as a scatter on the axis (`ax`) of the figure

ax.axis('equal')           # set equal axes as we work in UTM
# Out:
# (1.1205, 3.0895, 0.866, 2.054)

# %% [markdown]
# ### scatter plot with seaborn

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_LH_0,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
df_solutions_of_LH_0_1 = pd.read_csv('Ne_unstable_solutions_of_LHH=0.1_with_logs.csv')   # import a csv in a dataframe
df_solutions_of_LH_0_1
# Out:
#       LSiSi/LNaNa LSiSi/LHH  log_a  log_b
# 0               b         c   1.21   1.92
# 1               b         c   1.21   1.93
# 2               b         c   1.21   1.94
# 3               b         c   1.21   1.95
# 4               b         c   1.21   1.96
# ...           ...       ...    ...    ...
# 17258           b         c   3.00   1.96
# 17259           b         c   3.00   1.97
# 17260           b         c   3.00   1.98
# 17261           b         c   3.00   1.99
# 17262           b         c   3.00   2.00
#
# [17263 rows x 4 columns]

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_LH_0_1,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
df_solutions_of_non_Ab_Ne_LH_0 = pd.read_csv('solutions_of_unstable_Ne-Ab_and_LHH=0_with_logs.csv')   # import a csv in a dataframe
df_solutions_of_non_Ab_Ne_LH_0
# Out:
#       LSiSi/LNaNa LSiSi/LHH  log_a  log_b
# 0               b         c   -1.0  -1.00
# 1               b         c   -1.0  -0.99
# 2               b         c   -1.0  -0.98
# 3               b         c   -1.0  -0.97
# 4               b         c   -1.0  -0.96
# ...           ...       ...    ...    ...
# 61570           b         c    3.0   0.87
# 61571           b         c    3.0   0.88
# 61572           b         c    3.0   0.89
# 61573           b         c    3.0   0.90
# 61574           b         c    3.0   0.91
#
# [61575 rows x 4 columns]

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_non_Ab_Ne_LH_0,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
df_solutions_of_stable_Ab_Ne_LH_0 = pd.read_csv('solutions_of_stable_Ne-Ab_and_LHH=0_with_logs.csv')   # import a csv in a dataframe
df_solutions_of_stable_Ab_Ne_LH_0
# Out:
#       LSiSi/LNaNa LSiSi/LHH  log_a  log_b
# 0               b         c   1.21   1.92
# 1               b         c   1.21   1.93
# 2               b         c   1.21   1.94
# 3               b         c   1.21   1.95
# 4               b         c   1.21   1.96
# ...           ...       ...    ...    ...
# 17258           b         c   3.00   1.96
# 17259           b         c   3.00   1.97
# 17260           b         c   3.00   1.98
# 17261           b         c   3.00   1.99
# 17262           b         c   3.00   2.00
#
# [17263 rows x 4 columns]

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_stable_Ab_Ne_LH_0,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
# here, we combine a heat map using histplot and a subtle scatter plot to show the actual data.
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_stable_Ab_Ne_LH_0,color='black',linewidth=0,s=19,ax=ax1,zorder=4)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_non_Ab_Ne_LH_0,color='blue',linewidth=0,s=19,ax=ax1,zorder=2)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_LH_0,color='red', linewidth=0,s=19,ax=ax1, zorder=3)
plt.tight_layout()

# %%
df_solutions_of_no_Anl_in_layer_3_and_LHH_0 = pd.read_csv('solutions_of_no_Anl_in_layer_3_and_LHH=0_with_logs.csv')   # import a csv in a dataframe
df_solutions_of_no_Anl_in_layer_3_and_LHH_0
# Out:
#      LSiSi/LNaNa LSiSi/LHH  log_a  log_b
# 0              b         c   0.21  -0.45
# 1              b         c   0.21  -0.44
# 2              b         c   0.22  -0.51
# 3              b         c   0.22  -0.50
# 4              b         c   0.22  -0.49
# ...          ...       ...    ...    ...
# 5106           b         c   3.00  -0.14
# 5107           b         c   3.00  -0.13
# 5108           b         c   3.00  -0.12
# 5109           b         c   3.00  -0.11
# 5110           b         c   3.00  -0.10
#
# [5111 rows x 4 columns]

# %%
# here, we combine a heat map using histplot and a subtle scatter plot to show the actual data.
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_stable_Ab_Ne_LH_0,color='black',linewidth=0,s=19,ax=ax1,zorder=4)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_non_Ab_Ne_LH_0,color='blue',linewidth=0,s=19,ax=ax1,zorder=2)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_LH_0,color='red', linewidth=0,s=19,ax=ax1, zorder=3)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_no_Anl_in_layer_3_and_LHH_0,color='yellow',linewidth=0,s=19,ax=ax1,zorder=4)
plt.tight_layout()

# %%
df_solutions_of_unstable_Anl_in_layer_3_and_LHH_0 = pd.read_csv('solutions_of_unstable_Anl_in_layer_3_and_LHH=0_with_logs.csv')   # import a csv in a dataframe
df_solutions_of_unstable_Anl_in_layer_3_and_LHH_0
# Out:
#      LSiSi/LNaNa LSiSi/LHH  log_a  log_b
# 0              b         c  -0.55  -1.00
# 1              b         c  -0.54  -1.00
# 2              b         c  -0.54  -0.99
# 3              b         c  -0.53  -1.00
# 4              b         c  -0.53  -0.99
# ...          ...       ...    ...    ...
# 6551           b         c   3.00  -0.14
# 6552           b         c   3.00  -0.13
# 6553           b         c   3.00  -0.12
# 6554           b         c   3.00  -0.11
# 6555           b         c   3.00  -0.10
#
# [6556 rows x 4 columns]

# %%
# here, we combine a heat map using histplot and a subtle scatter plot to show the actual data.
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_stable_Ab_Ne_LH_0,color='black',linewidth=0,s=19,ax=ax1,zorder=4)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_non_Ab_Ne_LH_0,color='blue',linewidth=0,s=19,ax=ax1,zorder=2)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_LH_0,color='red', linewidth=0,s=19,ax=ax1, zorder=3)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_no_Anl_in_layer_3_and_LHH_0,color='yellow',linewidth=0,s=19,ax=ax1,zorder=6)
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_unstable_Anl_in_layer_3_and_LHH_0,color='green',linewidth=0,s=19,ax=ax1,zorder=5)
plt.tight_layout()

# %%
df_solutions_of_stable_Ne_Anl_and_LHH_0_many_value = pd.read_csv('solutions_of_stable_Ne_Anl_layer_and_LHH=0_many_value_with_logs.csv')   # import a csv in a dataframe
df_solutions_of_stable_Ne_Anl_and_LHH_0_many_value
# Out:
#       LSiSi/LNaNa LSiSi/LHH  log_a  log_b
# 0               b         c   1.20   2.03
# 1               b         c   1.20   2.04
# 2               b         c   1.21   1.92
# 3               b         c   1.21   1.93
# 4               b         c   1.21   1.94
# ...           ...       ...    ...    ...
# 54116           b         c   4.00   2.96
# 54117           b         c   4.00   2.97
# 54118           b         c   4.00   2.98
# 54119           b         c   4.00   2.99
# 54120           b         c   4.00   3.00
#
# [54121 rows x 4 columns]

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_a',y='log_b',data=df_solutions_of_stable_Ne_Anl_and_LHH_0_many_value,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
df_coefficients = pd.read_csv('coefficients_of_every_a_and_b.csv')
df_coefficients
# Out:
#         LSiSi/LNaNa  LSiSi/LAlAl     v1_Ab     v1_Ne     v2_Ab     v2_Ne  \
# 0               0.1     0.100000 -0.581189 -0.285622  0.281159  0.165610
# 1               0.1     0.102337 -0.580093 -0.288786  0.280063  0.168774
# 2               0.1     0.104729 -0.579012 -0.291905  0.278982  0.171893
# 3               0.1     0.107177 -0.577947 -0.294977  0.277917  0.174965
# 4               0.1     0.109682 -0.576899 -0.298005  0.276869  0.177993
# ...             ...          ...       ...       ...       ...       ...
# 119995       1000.0    91.172995 -0.246364 -0.748325 -0.053666  0.628313
# 119996       1000.0    93.303872 -0.246231 -0.748596 -0.053799  0.628584
# 119997       1000.0    95.484551 -0.246100 -0.748861 -0.053930  0.628849
# 119998       1000.0    97.716197 -0.245973 -0.749120 -0.054057  0.629108
# 119999       1000.0   100.000000 -0.245848 -0.749373 -0.054182  0.629361
#
#           v2_Anl    v3_Anl         v3_Ab    v4_Anl
# ...

# %% [markdown]
# ###　各相安定の条件式付け

# %%
stable_set_df = df_coefficients[(df_coefficients['v1_Ne'] < 0 ) & (df_coefficients['v2_Ne'] > 0) & (df_coefficients['v1_Ab'] < 0) & (df_coefficients['v2_Ab'] > 0) & (df_coefficients['v2_Anl'] < 0) & (df_coefficients['v3_Anl'] > 0) & (df_coefficients['v3_Ab'] < 0) & (df_coefficients['v4_Anl'] < 0)]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_df = stable_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]

# %%
# 結果を表示
print(stable_df)
# Out:
#         LSiSi/LNaNa  LSiSi/LAlAl
# 0               0.1     0.100000
# 1               0.1     0.102337
# 2               0.1     0.104729
# 3               0.1     0.107177
# 4               0.1     0.109682
# ...             ...          ...
# 119886       1000.0     7.348873
# 119887       1000.0     7.520629
# 119888       1000.0     7.696400
# 119889       1000.0     7.876279
# 119890       1000.0     8.060361
#
# [41750 rows x 2 columns]

# %%
stable_df
# Out:
#         LSiSi/LNaNa  LSiSi/LAlAl
# 0               0.1     0.100000
# 1               0.1     0.102337
# 2               0.1     0.104729
# 3               0.1     0.107177
# 4               0.1     0.109682
# ...             ...          ...
# 119886       1000.0     7.348873
# 119887       1000.0     7.520629
# 119888       1000.0     7.696400
# 119889       1000.0     7.876279
# 119890       1000.0     8.060361
#
# [41750 rows x 2 columns]

# %%
# insert a log version of area and stream power for later
stable_df.insert(1,  "log_(LSiSi/LNaNa)", np.log10(stable_df["LSiSi/LNaNa"].values))
stable_df.insert(3,  "log_(LSiSi/LAlAl)", np.log10(stable_df["LSiSi/LAlAl"].values))

stable_df
# Out:
#         LSiSi/LNaNa  log_(LSiSi/LNaNa)  LSiSi/LAlAl  log_(LSiSi/LAlAl)
# 0               0.1               -1.0     0.100000          -1.000000
# 1               0.1               -1.0     0.102337          -0.989967
# 2               0.1               -1.0     0.104729          -0.979933
# 3               0.1               -1.0     0.107177          -0.969900
# 4               0.1               -1.0     0.109682          -0.959866
# ...             ...                ...          ...                ...
# 119886       1000.0                3.0     7.348873           0.866221
# 119887       1000.0                3.0     7.520629           0.876254
# 119888       1000.0                3.0     7.696400           0.886288
# 119889       1000.0                3.0     7.876279           0.896321
# 119890       1000.0                3.0     8.060361           0.906355
#
# [41750 rows x 4 columns]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_df = stable_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]

# %% [markdown]
# ### pythonでの計算結果

# %%
df_coefficients_1 = pd.read_csv('coefficients_of_every_a_and_b_1.csv')
df_coefficients_1
# Out:
#        LSiSi/LNaNa  LSiSi/LAlAl     v1_Ab     v1_Ne     v2_Ab     v2_Ne  \
# 0              0.1     0.100000 -0.581189 -0.285622  0.281159  0.165610
# 1              0.1     0.104745 -0.579005 -0.291925  0.278975  0.171913
# 2              0.1     0.109716 -0.576885 -0.298045  0.276855  0.178033
# 3              0.1     0.114922 -0.574828 -0.303982  0.274798  0.183970
# 4              0.1     0.120375 -0.572833 -0.309739  0.272803  0.189727
# ...            ...          ...       ...       ...       ...       ...
# 29995       1000.0    83.073611 -0.246933 -0.747168 -0.053097  0.627156
# 29996       1000.0    87.015639 -0.246643 -0.747758 -0.053387  0.627746
# 29997       1000.0    91.144726 -0.246366 -0.748321 -0.053664  0.628309
# 29998       1000.0    95.469747 -0.246101 -0.748859 -0.053929  0.628847
# 29999       1000.0   100.000000 -0.245848 -0.749373 -0.054182  0.629361
#
#          v2_Anl        v3_Anl         v3_Ab        v4_Anl
# ...

# %%
stable_set_df_1 = df_coefficients_1[(df_coefficients_1['v1_Ne'] * df_coefficients_1['v1_Ab'] > 0 ) & (df_coefficients_1['v2_Ne'] * df_coefficients_1['v2_Ab'] > 0)]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_df_1 = stable_set_df_1[['LSiSi/LNaNa', 'LSiSi/LAlAl']]

# %%
stable_df_1
# Out:
#        LSiSi/LNaNa  LSiSi/LAlAl
# 0              0.1     0.100000
# 1              0.1     0.104745
# 2              0.1     0.109716
# 3              0.1     0.114922
# 4              0.1     0.120375
# ...            ...          ...
# 29941       1000.0     6.795396
# 29942       1000.0     7.117853
# 29943       1000.0     7.455611
# 29944       1000.0     7.809396
# 29945       1000.0     8.179969
#
# [19176 rows x 2 columns]

# %%
# insert a log version of area and stream power for later
stable_df_1.insert(1,  "log_(LSiSi/LNaNa)", np.log10(stable_df_1["LSiSi/LNaNa"].values))
stable_df_1.insert(3,  "log_(LSiSi/LAlAl)", np.log10(stable_df_1["LSiSi/LAlAl"].values))

stable_df_1
# Out:
#        LSiSi/LNaNa  log_(LSiSi/LNaNa)  LSiSi/LAlAl  log_(LSiSi/LAlAl)
# 0              0.1               -1.0     0.100000          -1.000000
# 1              0.1               -1.0     0.104745          -0.979866
# 2              0.1               -1.0     0.109716          -0.959732
# 3              0.1               -1.0     0.114922          -0.939597
# 4              0.1               -1.0     0.120375          -0.919463
# ...            ...                ...          ...                ...
# 29941       1000.0                3.0     6.795396           0.832215
# 29942       1000.0                3.0     7.117853           0.852349
# 29943       1000.0                3.0     7.455611           0.872483
# 29944       1000.0                3.0     7.809396           0.892617
# 29945       1000.0                3.0     8.179969           0.912752
#
# [19176 rows x 4 columns]

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_df_1,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %% [markdown]
# ### $v_2^{Ne} = 0$

# %%
stable_set_df_2 = df_coefficients_1[(df_coefficients_1['v2_Ne'] < 10**(-2)) & (-10**(-2) < df_coefficients_1['v2_Ne'])]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_df_2 = stable_set_df_2[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
stable_df_2
# Out:
#        LSiSi/LNaNa  LSiSi/LAlAl
# 3150      0.264308     0.100000
# 3300      0.276829     0.100000
# 3301      0.276829     0.104745
# 3450      0.289942     0.100000
# 3451      0.289942     0.104745
# ...            ...          ...
# 29295   830.994195     0.805453
# 29445   870.359136     0.805453
# 29595   911.588830     0.805453
# 29745   954.771611     0.805453
# 29895  1000.000000     0.805453
#
# [264 rows x 2 columns]

# %%
# insert a log version of area and stream power for later
stable_df_2.insert(1,  "log_(LSiSi/LNaNa)", np.log10(stable_df_2["LSiSi/LNaNa"].values))
stable_df_2.insert(3,  "log_(LSiSi/LAlAl)", np.log10(stable_df_2["LSiSi/LAlAl"].values))

stable_df_2
# Out:
#        LSiSi/LNaNa  log_(LSiSi/LNaNa)  LSiSi/LAlAl  log_(LSiSi/LAlAl)
# 3150      0.264308          -0.577889     0.100000          -1.000000
# 3300      0.276829          -0.557789     0.100000          -1.000000
# 3301      0.276829          -0.557789     0.104745          -0.979866
# 3450      0.289942          -0.537688     0.100000          -1.000000
# 3451      0.289942          -0.537688     0.104745          -0.979866
# ...            ...                ...          ...                ...
# 29295   830.994195           2.919598     0.805453          -0.093960
# 29445   870.359136           2.939698     0.805453          -0.093960
# 29595   911.588830           2.959799     0.805453          -0.093960
# 29745   954.771611           2.979899     0.805453          -0.093960
# 29895  1000.000000           3.000000     0.805453          -0.093960
#
# [264 rows x 4 columns]

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_df_2,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %% [markdown]
# ### こっから本番！！！

# %%
df_coefficients_2 = pd.read_csv('coefficients_of_every_a_and_b_ver2-3.csv')
df_coefficients_2
# Out:
#        LSiSi/LNaNa   LSiSi/LAlAl     v1_Ab     v1_Ne     v2_Ab     v2_Ne  \
# 0             10.0  3.162278e+00 -0.295457 -0.563867  0.153181  0.503826
# 1             10.0  3.342692e+00 -0.289834 -0.576123  0.147558  0.516082
# 2             10.0  3.533400e+00 -0.284417 -0.587931  0.142140  0.527890
# 3             10.0  3.734988e+00 -0.279201 -0.599298  0.136925  0.539258
# 4             10.0  3.948076e+00 -0.274184 -0.610233  0.131908  0.550193
# ...            ...           ...       ...       ...       ...       ...
# 74995   10000000.0  2.532879e+06 -0.057294 -0.958437 -0.084983  0.898397
# 74996   10000000.0  2.677385e+06 -0.057294 -0.958437 -0.084983  0.898397
# 74997   10000000.0  2.830135e+06 -0.057294 -0.958437 -0.084983  0.898397
# 74998   10000000.0  2.991601e+06 -0.057294 -0.958437 -0.084983  0.898397
# 74999   10000000.0  3.162278e+06 -0.057294 -0.958437 -0.084983  0.898397
#
#          v2_Anl        v3_Anl         v3_Ab        v4_Anl
# ...

# %% [markdown]
# ### 安定領域

# %%
stable_set_df_3 = df_coefficients_2[(df_coefficients_2['v1_Ne'] * df_coefficients_2['v1_Ab'] > 0 ) & (df_coefficients_2['v2_Ne']>0) & ( df_coefficients_2['v2_Ab'] < 0)]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_df_3 = stable_set_df_3[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
stable_df_3.insert(1,  "log_(LSiSi/LNaNa)", np.log10(stable_df_3["LSiSi/LNaNa"].values))
stable_df_3.insert(3,  "log_(LSiSi/LAlAl)", np.log10(stable_df_3["LSiSi/LAlAl"].values))
stable_df_3
# Out:
#         LSiSi/LNaNa  log_(LSiSi/LNaNa)   LSiSi/LAlAl  log_(LSiSi/LAlAl)
# 2328   1.515661e+01           1.180602  2.396172e+02           2.379518
# 2329   1.515661e+01           1.180602  2.532879e+02           2.403614
# 2330   1.515661e+01           1.180602  2.677385e+02           2.427711
# 2331   1.515661e+01           1.180602  2.830135e+02           2.451807
# 2332   1.515661e+01           1.180602  2.991601e+02           2.475904
# ...             ...                ...           ...                ...
# 74995  1.000000e+07           7.000000  2.532879e+06           6.403614
# 74996  1.000000e+07           7.000000  2.677385e+06           6.427711
# 74997  1.000000e+07           7.000000  2.830135e+06           6.451807
# 74998  1.000000e+07           7.000000  2.991601e+06           6.475904
# 74999  1.000000e+07           7.000000  3.162278e+06           6.500000
#
# [67127 rows x 4 columns]

# %% [markdown]
# ### 安定かもしれない領域

# %%
meta_stable_set_df_3 = df_coefficients_2[(df_coefficients_2['v1_Ne'] * df_coefficients_2['v1_Ab'] > 0 ) & (df_coefficients_2['v2_Ne']>0) & ( df_coefficients_2['v2_Ab'] > 0) & (df_coefficients_2['v1_Ab'] + df_coefficients_2['v2_Ab'] < 0)]
# 条件を満たすa, bの値だけを新しいDataFrameに格納
meta_stable_df_3 = meta_stable_set_df_3[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
meta_stable_df_3
# Out:
#        LSiSi/LNaNa  LSiSi/LAlAl
# 0             10.0     3.162278
# 1             10.0     3.342692
# 2             10.0     3.533400
# 3             10.0     3.734988
# 4             10.0     3.948076
# ...            ...          ...
# 74762   10000000.0     6.153988
# 74763   10000000.0     6.505086
# 74764   10000000.0     6.876214
# 74765   10000000.0     7.268517
# 74766   10000000.0     7.683201
#
# [7873 rows x 2 columns]

# %%
# insert a log version of area and stream power for later
meta_stable_df_3.insert(1,  "log_(LSiSi/LNaNa)", np.log10(meta_stable_df_3["LSiSi/LNaNa"].values))
meta_stable_df_3.insert(3,  "log_(LSiSi/LAlAl)", np.log10(meta_stable_df_3["LSiSi/LAlAl"].values))

sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=meta_stable_df_3,linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %% [markdown]
# ### $v_2^{Ne}=0$

# %%
v2_Ne_0_set_df = df_coefficients_2[(df_coefficients_2['v2_Ne'] < 10**(-2)) & (-10**(-2) < df_coefficients_2['v2_Ne'])]

# %% [markdown]
# ### $v_2^{Ab} = 0$

# %%
v2_Ab_0_set_df = df_coefficients_2[(df_coefficients_2['v2_Ab'] < 10**(-3)) & (-10**(-3) < df_coefficients_2['v2_Ab'])]

# %% [markdown]
# ### Ab/Ne

# %%
Ab_Ne_ratio_set_df = df_coefficients_2[abs(df_coefficients_2['v1_Ab']/ (df_coefficients_2['v1_Ne']+df_coefficients_2['v2_Ne'])- 0.9 ) < 10**(-1)]
Ab_Ne_ratio_df = Ab_Ne_ratio_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
Ab_Ne_ratio_df
# Out:
#         LSiSi/LNaNa   LSiSi/LAlAl
# 22148  5.832924e+02  1.164837e+04
# 22149  5.832924e+02  1.231293e+04
# 22150  5.832924e+02  1.301541e+04
# 22151  5.832924e+02  1.375797e+04
# 22152  5.832924e+02  1.454289e+04
# ...             ...           ...
# 74995  1.000000e+07  2.532879e+06
# 74996  1.000000e+07  2.677385e+06
# 74997  1.000000e+07  2.830135e+06
# 74998  1.000000e+07  2.991601e+06
# 74999  1.000000e+07  3.162278e+06
#
# [35190 rows x 2 columns]

# %%
Ab_Ne_ratio_set_df_over = df_coefficients_2[abs((df_coefficients_2['v1_Ab']) / (df_coefficients_2['v1_Ne']+df_coefficients_2['v2_Ne'])- 1.3 ) < 10**(-2)]
Ab_Ne_ratio_df_over = Ab_Ne_ratio_set_df_over[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
Ab_Ne_ratio_set_df_over_2 = df_coefficients_2[abs(df_coefficients_2['v1_Ab'] / (df_coefficients_2['v1_Ne']+df_coefficients_2['v2_Ne'])- 1.1 ) < 10**(-2)]
Ab_Ne_ratio_df_over_2 = Ab_Ne_ratio_set_df_over_2[['LSiSi/LNaNa', 'LSiSi/LAlAl']]

# %%
Ab_Ne_ratio_set_df_less = df_coefficients_2[abs(df_coefficients_2['v1_Ab'] / (df_coefficients_2['v1_Ne']+df_coefficients_2['v2_Ne'])- 2.5 ) < 10**(-1)]
Ab_Ne_ratio_df_less = Ab_Ne_ratio_set_df_less[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
Ab_Ne_ratio_set_df_less_2 = df_coefficients_2[abs(df_coefficients_2['v1_Ab'] / (df_coefficients_2['v1_Ne']+df_coefficients_2['v2_Ne'])- 4 ) < 10**(-1)]
Ab_Ne_ratio_df_less_2 = Ab_Ne_ratio_set_df_less_2[['LSiSi/LNaNa', 'LSiSi/LAlAl']]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
v2_Ne_0_df = v2_Ne_0_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
v2_Ab_0_df = v2_Ab_0_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
# insert a log version of area and stream power for later
v2_Ne_0_df.insert(1,  "log_(LSiSi/LNaNa)", np.log10(v2_Ne_0_df["LSiSi/LNaNa"].values))
v2_Ne_0_df.insert(3,  "log_(LSiSi/LAlAl)", np.log10(v2_Ne_0_df["LSiSi/LAlAl"].values))

v2_Ab_0_df.insert(1,  "log_(LSiSi/LNaNa)", np.log10(v2_Ab_0_df["LSiSi/LNaNa"].values))
v2_Ab_0_df.insert(3,  "log_(LSiSi/LAlAl)", np.log10(v2_Ab_0_df["LSiSi/LAlAl"].values))

Ab_Ne_ratio_df_over.insert(1,  "log_(LSiSi/LNaNa)", np.log10(Ab_Ne_ratio_df_over["LSiSi/LNaNa"].values))
Ab_Ne_ratio_df_over.insert(3,  "log_(LSiSi/LAlAl)", np.log10(Ab_Ne_ratio_df_over["LSiSi/LAlAl"].values))

Ab_Ne_ratio_df_over_2.insert(1,  "log_(LSiSi/LNaNa)", np.log10(Ab_Ne_ratio_df_over_2["LSiSi/LNaNa"].values))
Ab_Ne_ratio_df_over_2.insert(3,  "log_(LSiSi/LAlAl)", np.log10(Ab_Ne_ratio_df_over_2["LSiSi/LAlAl"].values))

Ab_Ne_ratio_df_less.insert(1,  "log_(LSiSi/LNaNa)", np.log10(Ab_Ne_ratio_df_less["LSiSi/LNaNa"].values))
Ab_Ne_ratio_df_less.insert(3,  "log_(LSiSi/LAlAl)", np.log10(Ab_Ne_ratio_df_less["LSiSi/LAlAl"].values))

Ab_Ne_ratio_df_less_2.insert(1,  "log_(LSiSi/LNaNa)", np.log10(Ab_Ne_ratio_df_less_2["LSiSi/LNaNa"].values))
Ab_Ne_ratio_df_less_2.insert(3,  "log_(LSiSi/LAlAl)", np.log10(Ab_Ne_ratio_df_less_2["LSiSi/LAlAl"].values))

Ab_Ne_ratio_df.insert(1,  "log_(LSiSi/LNaNa)", np.log10(Ab_Ne_ratio_df["LSiSi/LNaNa"].values))
Ab_Ne_ratio_df.insert(3,  "log_(LSiSi/LAlAl)", np.log10(Ab_Ne_ratio_df["LSiSi/LAlAl"].values))

sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=v2_Ne_0_df,color='red',linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=v2_Ab_0_df,color='blue',linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df,color='black',linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_over,color='green',linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_over_2,color='yellow',linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_less,color='orange',linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_less_2,color='white',linewidth=0,s=19,ax=ax1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
# here, we combine a heat map using histplot and a subtle scatter plot to show the actual data.
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_df_3,color='blue',linewidth=0,s=19,ax=ax1,zorder=2)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=v2_Ab_0_df,color='yellow', linewidth=0,s=19,ax=ax1, zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df,color='red',linewidth=0,s=19,ax=ax1, zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_over,color='green',linewidth=0,s=19,ax=ax1,zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_over_2,color='black',linewidth=0,s=19,ax=ax1,zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_less,color='orange',linewidth=0,s=19,ax=ax1,zorder=3)
plt.tight_layout()

# %%
v1_Ne_0_set_df = df_coefficients_2[(df_coefficients_2['v1_Ne'] < 10**(-2)) & (-10**(-2) < df_coefficients_2['v1_Ne'])]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
v2_Ne_0_df = v2_Ne_0_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
v2_Ab_0_df = v2_Ab_0_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
v1_Ne_0_df = v1_Ne_0_set_df[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
# insert a log version of area and stream power for later
v2_Ne_0_df.insert(1,  "log_(LSiSi/LNaNa)", np.log10(v2_Ne_0_df["LSiSi/LNaNa"].values))
v2_Ne_0_df.insert(3,  "log_(LSiSi/LAlAl)", np.log10(v2_Ne_0_df["LSiSi/LAlAl"].values))

v2_Ab_0_df.insert(1,  "log_(LSiSi/LNaNa)", np.log10(v2_Ab_0_df["LSiSi/LNaNa"].values))
v2_Ab_0_df.insert(3,  "log_(LSiSi/LAlAl)", np.log10(v2_Ab_0_df["LSiSi/LAlAl"].values))

v1_Ne_0_df.insert(1,  "log_(LSiSi/LNaNa)", np.log10(v1_Ne_0_df["LSiSi/LNaNa"].values))
v1_Ne_0_df.insert(3,  "log_(LSiSi/LAlAl)", np.log10(v1_Ne_0_df["LSiSi/LAlAl"].values))

sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_df_3,color='blue',linewidth=0,s=19,ax=ax1,zorder=2)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=meta_stable_df_3,color='green',linewidth=0,s=19,ax=ax1,zorder=2)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=v2_Ne_0_df,color='yellow', linewidth=0,s=19,ax=ax1, zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=v2_Ab_0_df,color='yellow', linewidth=0,s=19,ax=ax1, zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df,color='red',linewidth=0,s=19,ax=ax1, zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_over,color='green',linewidth=0,s=19,ax=ax1,zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=Ab_Ne_ratio_df_less,color='yellow',linewidth=0,s=19,ax=ax1,zorder=3)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=v1_Ne_0_df,color='black', linewidth=0,s=19,ax=ax1, zorder=3)
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame
fig.savefig('Onsagers_coefficients1.pdf')

# %%
df_coefficients_3 = pd.read_csv('coefficients_of_every_a_and_b_LHH_10-3.csv')
df_coefficients_3
# Out:
#        LSiSi/LNaNa  LSiSi/LAlAl     v1_Ab     v1_Ne     v2_Ab     v2_Ne  \
# 0             0.01     0.010000 -0.587607 -0.276687  0.287577  0.156675
# 1             0.01     0.010473 -0.585443 -0.283015  0.285413  0.163003
# 2             0.01     0.010969 -0.583342 -0.289161  0.283312  0.169149
# 3             0.01     0.011488 -0.581302 -0.295126  0.281272  0.175114
# 4             0.01     0.012032 -0.579324 -0.300913  0.279294  0.180901
# ...            ...          ...       ...       ...       ...       ...
# 74995     10000.00   831.148671 -0.240115 -0.760069 -0.059915  0.640057
# 74996     10000.00   870.480479 -0.240085 -0.760129 -0.059945  0.640117
# 74997     10000.00   911.673555 -0.240057 -0.760187 -0.059973  0.640175
# 74998     10000.00   954.815980 -0.240030 -0.760242 -0.060000  0.640230
# 74999     10000.00  1000.000000 -0.240004 -0.760294 -0.060026  0.640282
#
#          v2_Anl        v3_Anl         v3_Ab        v4_Anl
# ...

# %%
stable_set_df_3 = df_coefficients_3[(df_coefficients_3['v1_Ne'] * df_coefficients_3['v1_Ab'] > 0 ) & (df_coefficients_3['v2_Ne']>0) & (df_coefficients_3['v2_Ab'] < 0)]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_set_df_H = stable_set_df_3[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
# insert a log version of area and stream power for later
stable_set_df_H.insert(1,  "log_(LSiSi/LNaNa)", np.log10(stable_set_df_H["LSiSi/LNaNa"].values))
stable_set_df_H.insert(3,  "log_(LSiSi/LAlAl)", np.log10(stable_set_df_H["LSiSi/LAlAl"].values))

sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue', linewidth=0,s=19,ax=ax1, zorder=3)# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
stable_set_df_4 = df_coefficients_2[(df_coefficients_2['v1_Ne'] * df_coefficients_2['v1_Ab'] > 0 ) & (df_coefficients_2['v2_Ne']>0) & (df_coefficients_2['v2_Ab'] < 0)]

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_set_df_non_H = stable_set_df_4[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
# insert a log version of area and stream power for later
stable_set_df_non_H.insert(1,  "log_(LSiSi/LNaNa)", np.log10(stable_set_df_non_H["LSiSi/LNaNa"].values))
stable_set_df_non_H.insert(3,  "log_(LSiSi/LAlAl)", np.log10(stable_set_df_non_H["LSiSi/LAlAl"].values))

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, [ax1, ax2, ax3] = plt.subplots(figsize
                               =(8, 3),ncols=3)
# now using `seaborn` on the ax2, check how the data input differs
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_non_H,color='blue', linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue', linewidth=0,s=19,ax=ax2)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue',linewidth=0,s=19,ax=ax3,zorder=1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_non_H,color='yellow', alpha=0.1, linewidth=0,s=19,ax=ax3, zorder=2)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
ax2.axis('equal')
ax3.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
df_coefficients_4 = pd.read_csv('coefficients_of_every_a_and_b_LHH_10-2.csv')
df_coefficients_4
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_coefficients_4 = pd.read_csv('coefficients_of_every_a_and_b_LHH_10-2.csv')
#       2 df_coefficients_4
#
# File ~/anaconda3/envs/pythonenv/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pythonenv/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
# 条件を満たすa, bの値だけを新しいDataFrameに格納
stable_set_df_H_10_2 = stable_set_df_4[['LSiSi/LNaNa', 'LSiSi/LAlAl']]
# insert a log version of area and stream power for later
stable_set_df_H_10_2.insert(1,  "log_(LSiSi/LNaNa)", np.log10(stable_set_df_H["LSiSi/LNaNa"].values))
stable_set_df_H_10_2.insert(3,  "log_(LSiSi/LAlAl)", np.log10(stable_set_df_H["LSiSi/LAlAl"].values))

sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, ax1 = plt.subplots(figsize=(8, 6),ncols=1)

# using seaborn to make a graph
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H_10_2,color='blue', linewidth=0,s=19,ax=ax1, zorder=3)# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
plt.tight_layout() # important to pack everything within the frame

# %%
sns.set_theme()   # set the seaborn basic theme as a default (light grey background with white grid)

# create a figure and define the axes within it, set two axes side-by-side
fig, [[ax1, ax2, ax3], [ax4, ax5, ax6]] = plt.subplots(figsize
                               =(8, 5),ncols=3, nrows=2)
# now using `seaborn` on the ax2, check how the data input differs
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_non_H,color='blue', linewidth=0,s=19,ax=ax1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue', linewidth=0,s=19,ax=ax2)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H_10_2,color='blue', linewidth=0,s=19,ax=ax3)

sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue',linewidth=0,s=19,ax=ax4,zorder=1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_non_H,color='yellow', alpha=0.1, linewidth=0,s=19,ax=ax4, zorder=2)

sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue',linewidth=0,s=19,ax=ax5,zorder=1)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H_10_2,color='yellow', alpha=0.1, linewidth=0,s=19,ax=ax5, zorder=2)

sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H_10_2,color='yellow',alpha=0.1, linewidth=0,s=19,ax=ax6,zorder=2)
sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_non_H,color='blue', alpha=1, linewidth=0,s=19,ax=ax6, zorder=1)
# `s` sets the size of the dots
# `linewidth` sets the thickenss of a the outline of each dot. Set to zero when the points are overlapping closely

ax1.axis('equal')
ax2.axis('equal')
ax3.axis('equal')
ax4.axis('equal')
ax5.axis('equal')
ax6.axis('equal')
plt.tight_layout() # important to pack everything within the frame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 9
#       7 sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_non_H,color='blue', linewidth=0,s=19,ax=ax1)
#       8 sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue', linewidth=0,s=19,ax=ax2)
# ----> 9 sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H_10_2,color='blue', linewidth=0,s=19,ax=ax3)
#      11 sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_H,color='blue',linewidth=0,s=19,ax=ax4,zorder=1)
#      12 sns.scatterplot(x='log_(LSiSi/LNaNa)',y='log_(LSiSi/LAlAl)',data=stable_set_df_non_H,color='yellow', alpha=0.1, linewidth=0,s=19,ax=ax4, zorder=2)
#
# NameError: name 'stable_set_df_H_10_2' is not defined
